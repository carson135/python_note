# %% [markdown]
# ## keyboard shortcut
# Run: Shift + Enter (move next cell) or Ctr + Enter (stay the cell)
# Move to other cell: ESC (escape to current cell) + j / k key to up / down cell
# Add / Remove cell: ESC, a to add a cell above current cell, or b to add cell below current cell, dd to remove cell
# Change cell type: M for Markdown, Y for Code

# %% [markdown]
# default global variables and built-in functions are automatically available in the global namespace. These include special variables, built-in constants, and built-in functions, exceptions. Here are some of the key default global variables and built-ins that are set when running a Python script:
#
# Exceptions: 'SyntaxError', 'SyntaxWarning', 'SystemError', 'SystemExit', 'TabError', 'TimeoutError'
#
# Globals:
# '__builtins__': <module 'builtins' (built-in)>

# %% [markdown]
# ## if 0/None/''/""/[]/()/{} , return False
# del, remove one item of list/ one key-value pair of dictionary

# %%
a = str()
b = list()
c = tuple()
d = int() # 0
e = float() # 0.0
f = None
g = dict()
#h = range(0)
i = set()  #only way to create enmpty set object

# for all above empty type variable, will be False after if keyword as below:

if not a: print('a == ""')
if not b: print('list() == []')
if not c: print('tuple() == ()')
if not d: print('d == 0')
if not e: print('e == 0.0')
if not f: print('f == None')
if not g: print('dictinary() == {}')
#if not h: print('range() == ')
if not i: print('set() == empty set object\n')

# and as below 

j = ''
k = []
l = ()
m = {}
if not j: print('j == ""')
if not k: print('k == []')
if not l: print('l == ()')
if not m: print('m == {}')
# Out:
# a == ""
# list() == []
# tuple() == ()
# d == 0
# e == 0.0
# f == None
# dictinary() == {}
# set() == empty set object
#
# j == ""
# k == []
# l == ()
# m == {}

# %%
a = ''
b = []
c = ()
d = 0
e = 0.0
f = None # no len()
g = {} # set and dic both use {} literal, if no any itme in it, python would take it as empty set by default, not dic, 
#h = range() ??
i = {}

print(len(a))
print(len(b))
print(len(c))
print(len(g))
print(len(i))
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ## type methods
#
# string:  + concatenation:, f-string, [x:y:-1] (slicing), replace(), split() return list object, space by default , "abc".join(string_list)
# the f prefix is used to create formatted string literals, also known as f-strings
#
# f-string: the content in {} could be : variable of string/int/float, call function, data expression, format numbers: f"{value:.2f}", use f-strings with triple quotes for multiline strings, escape brace f"{{abc }}" -> {abc}
# "{}a{}bc".formate(v1,v2)
#
# "abcstring".format() :
# Using ''.join() to convert the iterator to a string: a = reversed('abc')  print(''.joint(a))
# original_string = "Hello, world!"
# insert_string = "beautiful "
# position = 7
# new_string = "{}{}{}".format(original_string[:position], insert_string, original_string[position:])
# print(new_string)
#
# # reversed(string): not return a reversed string, and can't be printed
# returns an iterator that yields the elements of the input sequence in reverse order. However, directly printing the iterator object will not show the reversed content. Instead, it will display something like <list_reverseiterator object at 0x...>.
#
# Using a for loop to build the reversed string:
# string_list = list(original_string)
# for char in reversed(insert_string):
#     string_list.insert(position, char)
# new_string2 = ''.join(string_list)b
# print(new_string2)
#
# # list:
# list(string), append() (add the argument as one element to the end of list), extend() (add each element of the argument to the end of list), insert(), remove(item_value), pop(), poped(), [] (slice), sort(), index(), copy()
# a == b can be used to check whether valuse are equal for two list objects
#
# # dict:
# value can be any python object inluce list/dic..., key can be any immutable types(string, number, byte, boolean, tuple)
#      get(key,return default value) or get (key) retur None if don't exitst,
#      for k,v in o.items(), o.items() return a key-value dic_items class, can be converted to list
#      for/if k in o.keys() or o (equal o.keys() by default), o.keys() return dic_keys class object, can be converted to list object
#      for/if v in o.values(), same as above
#
#      Starting from Python 3.7, dictionaries maintain the insertion order of their keys. This means that when you iterate over a dictionary, the elements will be returned in the order they were added.
#      OrderedDict: from collections import OrderedDict (keep pair order according key order
#
#      Understanding which iterable types are ordered is important for tasks that rely on the sequence of elements, such as sorting, indexing, and iterating in a specific order.
#
# set: no duplicated member in set , no order compare to list and dic objecte, initialize by set(list object) to remove duplicated items
#
# # range(100,10,-20): commonly used in for loops to iterate over a sequence of numbers,
# list(range(4))
# use the range object in various functions that accept iterable arguments: sum(range(4))
# Checking variable value Membership: if a in range(20):
#
# del: remove one item of list/ one key-value pair of dictionary
#
# sorted(list object): return a new sorted list object, but original list object order would not be changed
#
# #
# print multil
# nes:
#  add quote at end of each output line, and add index from second output line able nam?

# %% [markdown]
# ## Immutable Types
# In Python, several built-in types are immutable, meaning that once an object of these types is created, its value cannot be changed. Here are the main immutable types in Python:
# string, tuple,
# number, i = 10  f = 3.14  c = 1 + 2j  # i += 1  # This creates a new integer object, rather than modifying the existing one
#
# boolean, b = True # b = not b  # This assigns a new boolean value, rather than modifying the existing one
# frozenset:fs = frozenset([1, 2, 3]), fs.add(4) will error
# byte:b = b"hello", b[0]=96 will error
#
# # Mutable Types
# list, dictionary, set
#
# # Immutable types can be safely shared and used as keys in dictionaries or elements in sets
#
# # the immutability of strings:
# In Python, the term "immutable" means that an object cannot be changed after it is created. When we say that strings are immutable, it means that once a string object is created, its value cannot be altered. Any operation that appears to modify a string actually creates a new string object.
#
# 1,Efficiency
# s1 = "hello"
# s2 = "hello"
# print(s1 is s2)  # Output: True (both reference the same string object, Python can optimize their storage and handling, only store one copy of the string in memory
# 2, Safety: Immutability ensures that strings cannot be changed accidentally, which can help prevent bugs in your code. When you pass a string to a function, you can be sure that the function won't modify the original string.
#
# In summary, the immutability of strings in Python means that any operation that modifies a string results in the creation of a new string object. This characteristic provides benefits in terms of efficiency and safety, making strings easier to work with in many programming scenarios.
#
# a = 'my string'
# b = a
# a is b == True, a and b refer to the same string object
#
# b = 'my_strin', then create a new string object, and b refer to the new one.
#
# copying a string in Python is straightforward due to the immutability of strings. You can use simple assignment, the str() function, or slicing to create a copy of a string.
#
# copy module is typically used for copying mutable objects, you can technically use it for strings as well.
#
# import copy
# original_string = "hello"
# copied_string = copy.copy(original_string)
#
# # what can be followed after 'in' keyword
# the in keyword is used to check for membership within various data structures or to iterate over them in loops. Here are some common types of objects that can be placed after the in keyword:
# string, list, tuple, set, dictionary, range , and custom iterable objects
#
# Custom Iterable Objects:
# Any object that implements the __iter__() method (making it an iterable) can be used with the in keyword. This includes custom classes that define their own __iter__() method.
#
# class MyIterable:
#     def __init__(self, data):
#         self.data = data
#     def __iter__(self):
#         return iter(self.data)
#
# In Python, the dict_keys object is a view object that provides a dynamic view on the dictionary's keys. This view object is iterable, which means it can be looped over, but it is not a list. However, it can be easily converted to a list using the list() function
#
# # 'is' and ==
# is checks for object identity (whether two variables refer to the same object in memory).
# == checks for value equality (whether two variables have the same value).
# when you need to check if two variables point to the same object, especially when comparing to None. For most other comparisons, especially with mutable objects, use == to check for value equality.

# %% [markdown]
# ## methods of checking if it is iterable object

# %%
# method 1
from collections.abc import Iterable

# Example objects
obj1 = [1, 2, 3]  # List
obj2 = 123        # Integer

# Check if the objects are iterable
print(isinstance(obj1, Iterable))  # Output: True
print(isinstance(obj2, Iterable))  # Output: False
print('\n')


# methond 2
obj1 = [1, 2, 3]  # List
obj2 = 123        # Integer

# Function to check if an object is iterable
def is_iterable(obj):
    try:
        iter(obj)
        return True
    except TypeError:
        return False

# Check if the objects are iterable
print(is_iterable(obj1))  # Output: True
print(is_iterable(obj2))  # Output: False
print(is_iterable(range(4)))
print(is_iterable(None))

print(is_iterable(b'abc'))

class MyIterable:
    def __init__(self, data):
        self.data = data
    def __iter__(self):
        return iter(self.data)

abc = MyIterable('tes')
print(is_iterable(abc))

if 2 in obj1: print('t in abc')
else: print('no no')
# Out:
# True
# False
#
#
# True
# False
# True
# False
# True
# True
# t in abc

# %% [markdown]
# ## Difference between for loop and while loop:
#
# for loop: Used when you know the number of iterations in advance. It iterates over a sequence (like a list, tuple, string, or range).
# while loop: Used when the number of iterations is not known in advance. It continues to loop as long as the condition is true.

# %% [markdown]
# ## function
# #1, Variable-length Parameters:
#
# #2, runable code: global name: __name__
#
# #3, namespaces:
# Namespaces in Python help organize and manage the scope of variables.
# Built-in Namespace: Contains built-in functions and exceptions.
# Global Namespace: Contains names defined at the top level of a module or script.
# Local Namespace: Contains names defined within a function.
# Enclosing Namespace: Contains names in the local scope of any enclosing functi
#     enclosing functions refer to functions that contain other nested functions within their scope. The concept of enclosing functions is important when discussing nested functions and closures.
#     A closure occurs when an inner function remembers and can access variables from its enclosing function, even after the enclosing function has finished executing. Closures are often used for creating function factories or for maintaining state across function calls.
#   #  Closures ?
# A closure occurs when an inner function remembers and can access variables from its enclosing function, even after the enclosing function has finished executing. Closures are often used for creating function factories or for maintaining state across function calls.o
# ns.
# Use globals() and locals() to access global and local namespaces.
# Use nonlocal and global keywords to modify variables in enclosing and global namespaces, respect
#     global variables can be access in local namespace, but can't modify global value in local namespace, if want to do so, need use global keywrod to declare the global variable at local namespace.
#
#
# outer()
# y = "global"
#
# def modify_global():
#     global y
#     y = "modified"
#     print("Inside function:", y)
#
# modify_global()
# print("Ou
#
# def outer():
#     x = "outer"
#
#     def inner():
#         nonlocal x
#         x = "inner"
#         print("Inner:", x)
#
#     inner()
#     print("Outer:", x)
#
# outer()
# 4, function return value
# 5, function paremeters
# Positional Parameters: Specified in the function definition and must be provided in order.
# Default Parameters: Have default values that are used if no argument is provided.
# Keyword Parameters: Specified using parameter names, allowing arguments to be provided in any order.
# Variable-Length Positional Parameters (*args): Capture an arbitrary number of positional arguments as a tuple.
# Variable-Length Keyword Parameters (**kwargs): Capture an arbitrary number of keyword arguments as a dictionary.
# Positional-Only Parameters (/): Must be specified using positional arguments.
# Keyword-Only Parameters (*): Must be specified using keyword argu
#
# below def function Combining Different Types of Parameters like print(*arg, sep=' ', end='\n', file=None (default=sys.stdout), flush=False)
#
# def greet(greeting, /, name, age=25, *args, city="Unknown", **kwargs):
#     print(f"{greeting}, {name}. You are {age} years old and live in {city}.")
#     print("Additional args:", args)
#     print("Additional kwargs:", kwargs)
#
# greet("Hello", "Alice", 30, "extra1", "extra2", city="New York", hobby="Reading", profession="Engineer")
# # Output:
# # Hello, Alice. You are 30 years old and live in New York.
# # Additional args: ('extra1', 'extra2')
# # Additional kwargs: {'hobby': 'Reading', 'profession': 'E
#
# 6, build-in functions related iterable object
# # len(), range()
#
# # enumerate()
# Adds a counter to an iterable and returns it as an enumerate object. ?? enumerate
# # map()
# Applies a given function to all items in an iterable and returns a map object.
# # filter()
# Filters the items in an iterable based on a function that returns True or False
# # zip()
# Combines multiple iterables into a single iterator of tuples.
#
#
#
# # sorted(iterable object)
# Returns a new sorted list from the elements of any iterable.
# # reversed(iterable object)
# Returns a reversed iterator of the given sequence
# # iter(iterable object)
# Returns an iterator object. It is used to convert an iterable to an iterator
# # next(must be iterator object)
#
# # any(iterable object), all(iterable object),
# 7, build-in functions related with Object and Class Handling:
# # type()
# return a type object
# # isinstance()
# Checks if an object is an instance of a specified class or tuple of classes
# print(isinstance("hello", str))        # Output: True
#
# print(isinstance(123, (int, float)))   # Output: Tru# issubclass()
# Checks if a class is a subclass of another class or a tuple of classes.
# # hasattr(), getattr(), setattr(), delattr()
# about object attributes methods
# # vars()  dont' know how to use it, must be custom defined class ?
# Returns the __dict__ attribute of an object, which is a dictionary containing the object's attributes.
# # dir()
# Returns a list of the attributes and methods of an object.
# # id()
# Returns the unique identifier of an object
# # callable()
# Checks if an object appears callable (i.e., if it can be called as a function).
#
# 8, String Handling
# # chr()
# The chr() function returns the string representing a character whose Unicode code point is the integer passed as an argument.
# # ord()
# The ord() function returns an integer representing the Unicode code point of the given Unicode character
# # format(), return a str object, format(345.5642, ".2f")
# The format() function formats a specified value into a specified format. It is often used for string formatting.
# # ascii(), output unicode of the string, can be taked to call chr() one by one
# The ascii() function returns a string containing a printable representation of an object, but it escapes non-ASCII characters with \x, \u, or \U escapes
#
# 9, Utility Functions:
# # help(modules/classes/functions/keywords/etc)
# display the documentation of modules, classes, functions, keywords, etc,
# # eval()
# parses the expression passed to it and runs Python expression (code) within the program.
# # exec()
# executes the dynamically created Python code. It can execute a block of code, including statements.
# code = """
# def greet(name):
#     print(f'Hello, {name}')
#
# greet('Alice')
# """
# exec(code)
# # compile()
# The compile() function compiles the source into a code or AST object. The code object can be executed by exec() or e# globals(), locals(), memoryview(), object(), property()
# # staticmethod()
# The staticmethod() function returns a static method for a function.
# # classmethod()
# The classmethod() function returns a class method for a function
# # super()
# The super() function returns a temporary object of the superclass that allows access to its methods.v
# 10l()
#
# e x
# 6, lambd, short expression code, mainly used in map(), filter(), ...
# 11, 'with' keyword
# commmonly use in file operation, open and close automatically, manage resource, also used to open and close connection with DB and internet.a funct
#
#
# ion
# ngineer'}ments.tside function:", y)ively.

# %%
# Functions can accept a variable number of arguments using *args and **kwargs.

def print_numbers(*args):
    for number in args:
        print(number)

print_numbers(1, 2, 3)  # Output: 1 2 3

def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

print_info(name="Alice", age=30)  # Output: name: Alice, age: 30
# Out:
# 1
# 2
# 3
# name: Alice
# age: 30

# %%
# my_module.py
import argparse

def greet(name):
    return f"Hello, {name}!"

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Greet someone")
    parser.add_argument("name", help="Name of the person to greet")
    args = parser.parse_args()

    print(greet(args.name))
# Out:
# usage: ipykernel_launcher.py [-h] name
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\86186\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## iteration
# “迭代”是一个常用的术语，特别是在计算机科学和数学领域。它的基本含义是重复执行某一过程，每次重复称为一次迭代。通过多次迭代，逐步逼近目标或解决问题。
#
# 迭代的具体含义和应用
# 数学中的迭代：
# 在数学中，迭代通常指应用一个函数到一个初始值上，然后将结果再次应用到该函数上，如此反复进行。例如，牛顿迭代法用于求解方程的根。
#
# 编程中的迭代：
# 在编程中，迭代通常指使用循环结构（如for循环或while循环）来重复执行一段代码。每次循环执行的过程
#
# 软件开发中的迭代：
# 在软件开发中，迭代开发是一种方法论，其中开发过程被分为多个迭代周期，每个周期都包括规划、设计、开发和测试。这种方法论有助于逐步改进和完善软件产品
#
# 总结
# “迭代”在不同的领域有不同的具体应用，但其核心思想是通过重复执行某一过程来逐步逼近目标或解决问题。在编程中，迭代是实现循环和递归的重要概念；在数学中，迭代用于求解方程和优化问题；在软件开发中，迭代方法论有助于逐步构建和改进软件产品。。称为一次迭代。

# %%
# 牛顿迭代法求平方根
def sqrt_newton(n, iterations=10):
    x = n
    for _ in range(iterations):
        x = (x + n / x) / 2
    return x

print(sqrt_newton(29))  # 输出: 5.0
# Out:
# 5.385164807134505

# %% [markdown]
# ## special yufa
# a = [itme**2 for item in list object/range()]
